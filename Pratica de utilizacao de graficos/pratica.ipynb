# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tabela = pd.read_csv("dados.csv",sep=";")
display(tabela)
# Out:
#      CODIGO                MUNICIPIO       PIB  VALOREMPENHO
# 0       106    SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1       113             SANTO ANGELO  16575.82     800669.92
# 2       118   SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3        13          CACAPAVA DO SUL  13674.54     485535.86
# 4       120              SAO GABRIEL  19912.38     533719.86
# ..      ...                      ...       ...           ...
# 182     372  SANTA VITORIA DO PALMAR  27170.89        760.00
# 183     107     SANTA BARBARA DO SUL  29654.02        365.00
# 184      54           GETULIO VARGAS  16876.33        233.01
# 185     382          NOVA SANTA RITA  25938.38        310.58
# 186      60      GUARANI DAS MISSOES  24363.31        172.13
#
# [187 rows x 4 columns]

# %%
sns.histplot(tabela.PIB, kde=True, bins=10).set(title='PIB')
# Out:
# [Text(0.5, 1.0, 'PIB')]

# %%
sns.histplot(tabela.VALOREMPENHO,color="green",bins=10).set(title='VALOR EMPENHO')
# Out:
# [Text(0.5, 1.0, 'VALOR EMPENHO')]

# %%
sns.kdeplot(tabela.VALOREMPENHO,color="blue").set(title = "Densidade Valor Empenho")
# Out:
# [Text(0.5, 1.0, 'Densidade Valor Empenho')]

# %%
dados_selec = tabela[["PIB","VALOREMPENHO"]]
dados_selec.hist(bins=20, alpha=0.7, figsize=(15, 5))
# Out:
# array([[<Axes: title={'center': 'PIB'}>,
#         <Axes: title={'center': 'VALOREMPENHO'}>]], dtype=object)

# %%
selec_aleatoria = tabela.sort_values('PIB').head(10)
selec_aleatoria.plot.bar(x='MUNICIPIO',y='PIB', color = 'gray')
# Out:
# <Axes: xlabel='MUNICIPIO'>

# %%
selec_aleatoria = tabela.sort_values("VALOREMPENHO").head(10)
selec_aleatoria.plot.bar(x="MUNICIPIO",y="VALOREMPENHO", color = "blue")
# Out:
# <Axes: xlabel='MUNICIPIO'>

# %%
tabela2 = pd.read_csv("trees.csv")
tabela2.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
plt.scatter(tabela2.Girth,tabela2.Volume,marker="*")
plt.title("Arvores Volume x Circunferencia")
plt.xlabel("Circunferencia")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %%
sns.regplot(x=tabela2.Volume, y=tabela2.Girth, data= tabela2,x_jitter=0.4, fit_reg=False)
# Out:
# <Axes: xlabel='Volume', ylabel='Girth'>

# %%
plt.boxplot(tabela2.Volume, vert = False, notch= True , patch_artist= True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25fc89927b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25fc8992a20>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x25fc88fe660>],
#  'medians': [<matplotlib.lines.Line2D at 0x25fc8993020>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25fc8993320>],
#  'means': []}

# %%
sns.boxenplot(data=tabela2, orient="h")
# Out:
# <Axes: >

# %%
plt.figure()
plt.subplot(3,2,1)
sns.histplot(tabela.PIB, kde=True, bins=10).set(title='PIB')
plt.subplot(3,2,2)
sns.kdeplot(tabela.VALOREMPENHO,color="blue").set(title = "Densidade Valor Empenho")
plt.subplot(3,2,3)
sns.regplot(x=tabela2.Volume, y=tabela2.Girth, data= tabela2,x_jitter=0.4, fit_reg=False)
plt.subplot(3,2,4)
sns.boxenplot(data=tabela2, orient="h")
plt.tight_layout()
